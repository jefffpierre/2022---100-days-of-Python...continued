# %%
#Step 1 

word_list = ["aardvark", "baboon", "camel"]

#TODO-1 - Randomly choose a word from the word_list and assign it to a variable called chosen_word.

import random 

chosen_word = random.choice(word_list)

#TODO-2 - Ask the user to guess a letter and assign their answer to a variable called guess. Make guess lowercase.

guess = input("Guess a letter: ").lower()

#TODO-3 - Check if the letter the user guessed (guess) is one of the letters in the chosen_word.

for letter in chosen_word:
    if letter == guess:
        print("Good")
    else:
        print("Nope")
# Out:
# Nope
# Good
# Nope
# Nope
# Nope
# Nope

# %%
#Step 2

import random
word_list = ["aardvark", "baboon", "camel"]
chosen_word = random.choice(word_list)

#Testing code
print(f'Pssst, the solution is {chosen_word}.')

#TODO-1: - Create an empty List called display.
#For each letter in the chosen_word, add a "_" to 'display'.
#So if the chosen_word was "apple", display should be ["_", "_", "_", "_", "_"] with 5 "_" representing each letter to guess.

#--Option 1--
# display = []
# for letter in chosen_word:
#     display += "_"
# print(display)

#--Option 2--

display = []
word_length = len(chosen_word)
for _ in range(word_length):
     display += "_"
print(display)

guess = input("Guess a letter: ").lower()


#TODO-2: - Loop through each position in the chosen_word;
#If the letter at that position matches 'guess' then reveal that letter in the display at that position.
#e.g. If the user guessed "p" and the chosen word was "apple", then display should be ["_", "p", "p", "_", "_"].
for position in range(word_length):
    letter = chosen_word[position]
    if letter == guess:
        display[position] = letter


#TODO-3: - Print 'display' and you should see the guessed letter in the correct position and every other letter replace with "_".
#Hint - Don't worry about getting the user to guess the next letter. We'll tackle that in step 3.
print(display)
# Out:
# Pssst, the solution is camel.
# ['_', '_', '_', '_', '_']
# ['_', 'a', '_', '_', '_']

# %%
#Step 3

import random
word_list = ["aardvark", "baboon", "camel"]
chosen_word = random.choice(word_list)
word_length = len(chosen_word)

#Testing code
print(f'Pssst, the solution is {chosen_word}.')

#Create blanks
display = []
for _ in range(word_length):
    display += "_"

#TODO-1: - Use a while loop to let the user guess again. The loop should only stop once the user has guessed all the letters in the chosen_word 
        #  and 'display' has no more blanks ("_"). Then you can tell the user they've won.

end_of_game = False

while not end_of_game:
    guess = input("Guess a letter: ").lower()


    #Check guessed letter
    for position in range(word_length):
        letter = chosen_word[position]
        print(f"Current position: {position}\n Current letter: {letter}\n Guessed letter: {guess}")
        if letter == guess:
            display[position] = letter

    print(display)
    
    #Check if user has got all letters.
    if "_" not in display:
        end_of_game = True
        print("Nice")
# Out:
# Pssst, the solution is aardvark.
# Current position: 0
#  Current letter: a
#  Guessed letter: a
# Current position: 1
#  Current letter: a
#  Guessed letter: a
# Current position: 2
#  Current letter: r
#  Guessed letter: a
# Current position: 3
#  Current letter: d
#  Guessed letter: a
# Current position: 4
#  Current letter: v
#  Guessed letter: a
# Current position: 5
#  Current letter: a
#  Guessed letter: a
# Current position: 6
#  Current letter: r
#  Guessed letter: a
# Current position: 7
#  Current letter: k
#  Guessed letter: a
# ['a', 'a', '_', '_', '_', 'a', '_', '_']
# Current position: 0
#  Current letter: a
#  Guessed letter: d
# Current position: 1
#  Current letter: a
#  Guessed letter: d
# Current position: 2
#  Current letter: r
#  Guessed letter: d
# Current position: 3
#  Current letter: d
#  Guessed letter: d
# Current position: 4
#  Current letter: v
#  Guessed letter: d
# Current position: 5
#  Current letter: a
#  Guessed letter: d
# Current position: 6
#  Current letter: r
#  Guessed letter: d
# Current position: 7
#  Current letter: k
#  Guessed letter: d
# ['a', 'a', '_', 'd', '_', 'a', '_', '_']
# Current position: 0
#  Current letter: a
#  Guessed letter: k
# Current position: 1
#  Current letter: a
#  Guessed letter: k
# Current position: 2
#  Current letter: r
#  Guessed letter: k
# Current position: 3
#  Current letter: d
#  Guessed letter: k
# Current position: 4
#  Current letter: v
#  Guessed letter: k
# Current position: 5
#  Current letter: a
#  Guessed letter: k
# Current position: 6
#  Current letter: r
#  Guessed letter: k
# Current position: 7
#  Current letter: k
#  Guessed letter: k
# ['a', 'a', '_', 'd', '_', 'a', '_', 'k']
# Current position: 0
#  Current letter: a
#  Guessed letter: v
# Current position: 1
#  Current letter: a
#  Guessed letter: v
# Current position: 2
#  Current letter: r
#  Guessed letter: v
# Current position: 3
#  Current letter: d
#  Guessed letter: v
# Current position: 4
#  Current letter: v
#  Guessed letter: v
# Current position: 5
#  Current letter: a
#  Guessed letter: v
# Current position: 6
#  Current letter: r
#  Guessed letter: v
# Current position: 7
#  Current letter: k
#  Guessed letter: v
# ['a', 'a', '_', 'd', 'v', 'a', '_', 'k']
# Current position: 0
#  Current letter: a
#  Guessed letter: r
# Current position: 1
#  Current letter: a
#  Guessed letter: r
# Current position: 2
#  Current letter: r
#  Guessed letter: r
# Current position: 3
#  Current letter: d
#  Guessed letter: r
# Current position: 4
#  Current letter: v
#  Guessed letter: r
# Current position: 5
#  Current letter: a
#  Guessed letter: r
# Current position: 6
#  Current letter: r
#  Guessed letter: r
# Current position: 7
#  Current letter: k
#  Guessed letter: r
# ['a', 'a', 'r', 'd', 'v', 'a', 'r', 'k']
# Nice

# %%
#Step 4

import random

stages = ['''
  +---+
  |   |
  O   |
 /|\  |
 / \  |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
 /    |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|   |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
  |   |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
      |
      |
      |
=========
''', '''
  +---+
  |   |
      |
      |
      |
      |
=========
''']

end_of_game = False

word_list = ["ardvark", "baboon", "camel"]
chosen_word = random.choice(word_list)
word_length = len(chosen_word)

#TODO-1: - Create a variable called 'lives' to keep track of the number of lives left. 
#Set 'lives' to equal 6.

lives = 6

#Testing code
print(f'Pssst, the solution is {chosen_word}.')

#Create blanks
display = []
for _ in range(word_length):
  display += "_"

while not end_of_game:
  guess = input("Guess a letter: ").lower()

  #Check guessed letter
  for position in range(word_length):
    letter = chosen_word[position]
    # print(f"Current position: {position}\n Current letter: {letter}\n Guessed letter: {guess}")
    if letter == guess:
      display[position] = letter
  
  if guess not in chosen_word:
    lives -= 1
    if lives == 0:
      end_of_game = True
      print("You lose.")

  #Join all the elements in the list and turn it into a String.
  print(f"{' '. join(display)}")

  #Check if user has got all letters.
  if "_" not in display:
    end_of_game = True
    print("You Win.")

  #TODO-3: - print the ASCII art from 'stages' that corresponds to the current number of 'lives' the user has remaining.
  print(stages[lives])

# %%
#Step 5
import os
#os.system('cls') # this line clears the screen 'cls' = windows

import random

#TODO-1: - Update the word list to use the 'word_list' from hangman_words.py

from hangman_words import word_list

chosen_word = random.choice(word_list)
word_length = len(chosen_word)

end_of_game = False
lives = 6

#TODO-3: - Import the logo from hangman_art.py and print it at the start of the game.

from hangman_art import logo
print(logo)

#Testing code
print(f'Pssss, the solution is {chosen_word}')

#Create blanks
display = []
for _ in range(word_length):
    display += "_"

while not end_of_game:
    guess = input("Guess a letter: ").lower()


    #TODO-4: - If the user has entered a letter they've already guessed, print the letter and let them know.
    if guess in display:
        print(f"You've already guessed the letter: {guess}")

    #Check guessed letter
    for position in range(word_length):
        letter = chosen_word[position]
        #print(f"Current position: {position}\n Current letter: {letter}\n Guessed letter: {guess}")
        if letter == guess:
            display[position] = letter

    #Check if user is wrong.
    if guess not in chosen_word:
        #TODO-5: - If the letter is not in the chosen_word, print out the letter and let them know it's not in the word.
        print(f"The letter {guess} is not in the word. You lose a life")
        lives -= 1
        if lives == 0:
            end_of_game
            print("You Lose.")


    
    #Join all the elements in the list and turn it into a String.
    print(f"{' '.join(display)}")

    #Check if user has got all letters.
    if "_" not in display:
        end_of_game = True
        print("You Win.")

    #TODO-2: - Import the stages from hangman_art.py and make this error go away

    from hangman_art import  stages

    print(stages[lives])
# Out:
#
#  _
# | |
# | |__   __ _ _ __   __ _ _ __ ___   __ _ _ __
# | '_ \ / _` | '_ \ / _` | '_ ` _ \ / _` | '_ \
# | | | | (_| | | | | (_| | | | | | | (_| | | | |
# |_| |_|\__,_|_| |_|\__, |_| |_| |_|\__,_|_| |_|
#                     __/ |
#                    |___/
# Pssss, the solution is spritz
# s _ _ _ _ _
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# =========
#
# s p _ _ _ _
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# =========
#
# s p _ _ _ z
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# =========
#
# The letter h is not in the word. You lose a life
# s p _ _ _ z
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
#
# The letter a is not in the word. You lose a life
# s p _ _ _ z
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# =========
#
# s p r _ _ z
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# =========
#
# s p r _ t z
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# =========
#
# The letter rw is not in the word. You lose a life
# s p r _ t z
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# =========
# The letter w is not in the word. You lose a life
# s p r _ t z
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#       |
#       |
# =========
#
# The letter a is not in the word. You lose a life
# s p r _ t z
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  /    |
#       |
# =========
#
# The letter f is not in the word. You lose a life
# You Lose.
# s p r _ t z
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  / \  |
#       |
# =========
#
# The letter g is not in the word. You lose a life
# s p r _ t z
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# =========
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17560/1876060014.py in <module>
#      29
#      30 while not end_of_game:
# ---> 31     guess = input("Guess a letter: ").lower()
#      32
#      33
#
# c:\Users\pierr\AppData\Local\Programs\Python\Python39\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     979                 "raw_input was called, but this frontend does not support input requests."
#     980             )
# --> 981         return self._input_request(
#     982             str(prompt),
#     983             self._parent_ident["shell"],
#
# c:\Users\pierr\AppData\Local\Programs\Python\Python39\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1024             except KeyboardInterrupt:
#    1025                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1026                 raise KeyboardInterrupt("Interrupted by user") from None
#    1027             except Exception as e:
#    1028                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
